# %%
from tensorflow.keras.datasets import mnist  
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.models import Sequential    
from tensorflow.keras.layers import Dense, Activation, Dropout  # 添加Dropout层

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])
print(X_train.shape)
print(X_test.shape)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
# Out:
# (60000, 784)
# (10000, 784)

# %%
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# %%
model = Sequential()  
model.add(Dense(500, input_dim=784))  
model.add(Activation('relu'))       # 将sigmoid替换为relu
model.add(Dropout(0.2))             # 添加Dropout层，丢弃率0.2
model.add(Dense(500))  
model.add(Activation('relu'))       # 将sigmoid替换为relu
model.add(Dropout(0.2))             # 添加Dropout层，丢弃率0.2
model.add(Dense(10))  
model.add(Activation('softmax'))    # 输出层保持softmax不变

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 500)               392500
#
#  activation_15 (Activation)  (None, 500)               0
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_16 (Dense)            (None, 500)               250500
#
#  activation_16 (Activation)  (None, 500)               0
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_17 (Dense)            (None, 10)                5010
#
#  activation_17 (Activation)  (None, 10)                0
#
# ...
# Total params: 648,010
# Trainable params: 648,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size=100, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2365 - accuracy: 0.9282
# Epoch 2/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0992 - accuracy: 0.9690
# Epoch 3/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0711 - accuracy: 0.9778
# Epoch 4/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0555 - accuracy: 0.9821
# Epoch 5/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0471 - accuracy: 0.9850
# Epoch 6/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0377 - accuracy: 0.9879
# Epoch 7/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0355 - accuracy: 0.9883
# Epoch 8/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0306 - accuracy: 0.9899
# Epoch 9/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0287 - accuracy: 0.9903
# Epoch 10/50
# ...

# %%
score = model.evaluate(X_test, Y_test)
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0996 - accuracy: 0.9831
# Test loss:  0.09964914619922638
# Test accuracy:  0.9830999970436096
