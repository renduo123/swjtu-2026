# %%
from tensorflow.keras.datasets import mnist  
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.models import Sequential    
from tensorflow.keras.layers import Dense, Activation

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])
print(X_train.shape)
print(X_test.shape)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
# Out:
# (60000, 784)
# (10000, 784)

# %%
Y_train =to_categorical(y_train, 10)
Y_test =to_categorical(y_test, 10)

# %%
model = Sequential() 
model.add(Dense(500, input_dim=784))
model.add(Activation('sigmoid'))
model.add(Dense(500))
model.add(Activation('sigmoid'))
model.add(Dense(10))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               392500
#
#  activation (Activation)     (None, 500)               0
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  activation_1 (Activation)   (None, 500)               0
#
#  dense_2 (Dense)             (None, 10)                5010
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 648,010
# Trainable params: 648,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'sgd', metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size=100, epochs=20)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0910 - accuracy: 0.1083
# Epoch 2/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0900 - accuracy: 0.1412
# Epoch 3/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0899 - accuracy: 0.1212
# Epoch 4/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0898 - accuracy: 0.1195
# Epoch 5/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0898 - accuracy: 0.1199
# Epoch 6/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0898 - accuracy: 0.1237
# Epoch 7/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0897 - accuracy: 0.1261
# Epoch 8/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0897 - accuracy: 0.1208
# Epoch 9/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0896 - accuracy: 0.1264
# Epoch 10/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0896 - accuracy: 0.1402
# Epoch 11/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0896 - accuracy: 0.1220
# Epoch 12/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0895 - accuracy: 0.1303
# Epoch 13/20
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0895 - accuracy: 0.1323
# Epoch 14/20
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0894 - accuracy: 0.1290
# Epoch 15/20
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0894 - accuracy: 0.1426
# Epoch 16/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0894 - accuracy: 0.1407
# Epoch 17/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0893 - accuracy: 0.1410
# Epoch 18/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0893 - accuracy: 0.1752
# Epoch 19/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0892 - accuracy: 0.1570
# Epoch 20/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0892 - accuracy: 0.1683

# %%
score = model.evaluate(X_test, Y_test)
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0892 - accuracy: 0.1687
# Test loss:  0.08916167169809341
# Test accuracy:  0.16869999468326569
