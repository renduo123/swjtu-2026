# %%
# 1. 导入库
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, BatchNormalization, Dropout
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
import numpy as np

# 2. 加载数据
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# 3. 数据预处理
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
Y_train = np_utils.to_categorical(y_train, 10)
Y_test = np_utils.to_categorical(y_test, 10)

# 4. 数据增强（移除亮度参数）
datagen = ImageDataGenerator(
    rotation_range=30,          
    width_shift_range=0.2,       
    height_shift_range=0.2,      
    horizontal_flip=True,
    vertical_flip=True,          
    zoom_range=0.2,              
    shear_range=0.2,             
    fill_mode='nearest'
)
datagen.fit(X_train)

# 5. 构建模型
model = Sequential()

# 第一层卷积块
model.add(Conv2D(32, (3,3), padding='same', input_shape=X_train.shape[1:], kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 第二层卷积块
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 第三层卷积块
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 全连接层
model.add(Flatten())
model.add(Dense(512, kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# 6. 编译模型
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# 7. 早停策略
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True
)

# 8. 训练模型
history = model.fit(
    datagen.flow(X_train, Y_train, batch_size=64),
    steps_per_epoch=len(X_train) // 64,
    epochs=50,
    validation_data=(X_test, Y_test),
    callbacks=[early_stopping]
)

# 9. 评估模型
score = model.evaluate(X_test, Y_test)
print(f'Test loss: {score[0]:.4f}')
print(f'Test accuracy: {score[1]:.4f}')
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3) (50000, 1) (10000, 1)
# Epoch 1/50
# 781/781 [==============================] - 93s 117ms/step - loss: 2.8729 - accuracy: 0.2264 - val_loss: 2.4314 - val_accuracy: 0.3205
# Epoch 2/50
# 781/781 [==============================] - 95s 121ms/step - loss: 2.5301 - accuracy: 0.2992 - val_loss: 2.1792 - val_accuracy: 0.3884
# Epoch 3/50
# 781/781 [==============================] - 99s 127ms/step - loss: 2.3706 - accuracy: 0.3403 - val_loss: 2.2940 - val_accuracy: 0.3702
# Epoch 4/50
# 781/781 [==============================] - 88s 113ms/step - loss: 2.2588 - accuracy: 0.3703 - val_loss: 2.1793 - val_accuracy: 0.4029
# Epoch 5/50
# 781/781 [==============================] - 73s 94ms/step - loss: 2.1650 - accuracy: 0.3970 - val_loss: 2.1234 - val_accuracy: 0.4152
# Epoch 6/50
# 781/781 [==============================] - 90s 116ms/step - loss: 2.0860 - accuracy: 0.4155 - val_loss: 1.9855 - val_accuracy: 0.4473
# Epoch 7/50
# 781/781 [==============================] - 97s 124ms/step - loss: 2.0032 - accuracy: 0.4381 - val_loss: 2.0156 - val_accuracy: 0.4420
# Epoch 8/50
# 781/781 [==============================] - 97s 124ms/step - loss: 1.9273 - accuracy: 0.4559 - val_loss: 2.1541 - val_accuracy: 0.4124
# Epoch 9/50
# 781/781 [==============================] - 99s 127ms/step - loss: 1.8636 - accuracy: 0.4704 - val_loss: 2.1012 - val_accuracy: 0.4104
# Epoch 10/50
# 781/781 [==============================] - 79s 102ms/step - loss: 1.8087 - accuracy: 0.4835 - val_loss: 1.7806 - val_accuracy: 0.4955
# Epoch 11/50
# 781/781 [==============================] - 74s 95ms/step - loss: 1.7520 - accuracy: 0.4983 - val_loss: 1.7788 - val_accuracy: 0.4898
# Epoch 12/50
# 781/781 [==============================] - 74s 94ms/step - loss: 1.7084 - accuracy: 0.5070 - val_loss: 1.8363 - val_accuracy: 0.4764
# Epoch 13/50
# 781/781 [==============================] - 74s 94ms/step - loss: 1.6618 - accuracy: 0.5205 - val_loss: 1.6748 - val_accuracy: 0.5211
# Epoch 14/50
# 781/781 [==============================] - 71s 91ms/step - loss: 1.6261 - accuracy: 0.5273 - val_loss: 1.7803 - val_accuracy: 0.4883
# Epoch 15/50
# 781/781 [==============================] - 75s 96ms/step - loss: 1.5887 - accuracy: 0.5354 - val_loss: 1.8586 - val_accuracy: 0.4715
# Epoch 16/50
# 781/781 [==============================] - 73s 94ms/step - loss: 1.5585 - accuracy: 0.5438 - val_loss: 1.7014 - val_accuracy: 0.5206
# Epoch 17/50
# 781/781 [==============================] - 94s 120ms/step - loss: 1.5208 - accuracy: 0.5524 - val_loss: 1.6125 - val_accuracy: 0.5133
# Epoch 18/50
# 781/781 [==============================] - 96s 123ms/step - loss: 1.4942 - accuracy: 0.5605 - val_loss: 1.5509 - val_accuracy: 0.5549
# Epoch 19/50
# 781/781 [==============================] - 725s 929ms/step - loss: 1.4344 - accuracy: 0.5736 - val_loss: 1.5259 - val_accuracy: 0.5596
# Epoch 21/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.4146 - accuracy: 0.5776 - val_loss: 1.4731 - val_accuracy: 0.5597
# Epoch 22/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.3934 - accuracy: 0.5844 - val_loss: 1.3902 - val_accuracy: 0.5818
# Epoch 23/50
# 781/781 [==============================] - 88s 113ms/step - loss: 1.3704 - accuracy: 0.5875 - val_loss: 1.3214 - val_accuracy: 0.6012
# Epoch 24/50
# 781/781 [==============================] - 97s 124ms/step - loss: 1.3508 - accuracy: 0.5940 - val_loss: 1.5305 - val_accuracy: 0.5454
# Epoch 25/50
# 781/781 [==============================] - 100s 127ms/step - loss: 1.3317 - accuracy: 0.6016 - val_loss: 1.3590 - val_accuracy: 0.6014
# Epoch 26/50
# 781/781 [==============================] - 97s 124ms/step - loss: 1.3107 - accuracy: 0.6042 - val_loss: 1.4487 - val_accuracy: 0.5665
# Epoch 27/50
# 781/781 [==============================] - 96s 123ms/step - loss: 1.3066 - accuracy: 0.6053 - val_loss: 1.2710 - val_accuracy: 0.6172
# Epoch 28/50
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2863 - accuracy: 0.6128 - val_loss: 1.1793 - val_accuracy: 0.6521
# Epoch 29/50
# 781/781 [==============================] - 98s 125ms/step - loss: 1.2710 - accuracy: 0.6180 - val_loss: 1.1725 - val_accuracy: 0.6428
# Epoch 30/50
# 781/781 [==============================] - 96s 123ms/step - loss: 1.2551 - accuracy: 0.6203 - val_loss: 1.2494 - val_accuracy: 0.6246
# Epoch 31/50
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2487 - accuracy: 0.6237 - val_loss: 1.1946 - val_accuracy: 0.6511
# Epoch 32/50
# 781/781 [==============================] - 4792s 6s/step - loss: 1.2322 - accuracy: 0.6277 - val_loss: 1.3041 - val_accuracy: 0.6119
# Epoch 33/50
# 781/781 [==============================] - 86s 109ms/step - loss: 1.2117 - accuracy: 0.6331 - val_loss: 1.2340 - val_accuracy: 0.6342
# Epoch 34/50
# 781/781 [==============================] - 89s 114ms/step - loss: 1.2109 - accuracy: 0.6333 - val_loss: 1.0830 - val_accuracy: 0.6814
# Epoch 35/50
# 781/781 [==============================] - 96s 123ms/step - loss: 1.1991 - accuracy: 0.6371 - val_loss: 1.2300 - val_accuracy: 0.6275
# Epoch 36/50
# 781/781 [==============================] - 97s 124ms/step - loss: 1.1880 - accuracy: 0.6391 - val_loss: 1.1189 - val_accuracy: 0.6727
# Epoch 37/50
# 781/781 [==============================] - 93s 119ms/step - loss: 1.1798 - accuracy: 0.6438 - val_loss: 1.0188 - val_accuracy: 0.6965
# Epoch 38/50
# 781/781 [==============================] - 113s 144ms/step - loss: 1.1689 - accuracy: 0.6452 - val_loss: 1.2138 - val_accuracy: 0.6360
# Epoch 39/50
# 781/781 [==============================] - 128s 164ms/step - loss: 1.1637 - accuracy: 0.6480 - val_loss: 1.1528 - val_accuracy: 0.6588
# Epoch 40/50
# 781/781 [==============================] - 122s 157ms/step - loss: 1.1484 - accuracy: 0.6523 - val_loss: 1.0757 - val_accuracy: 0.6774
# Epoch 41/50
# 781/781 [==============================] - 113s 145ms/step - loss: 1.1454 - accuracy: 0.6555 - val_loss: 1.0859 - val_accuracy: 0.6778
# Epoch 42/50
# 781/781 [==============================] - 114s 146ms/step - loss: 1.1344 - accuracy: 0.6558 - val_loss: 1.0960 - val_accuracy: 0.6753
# Epoch 43/50
# 781/781 [==============================] - 113s 144ms/step - loss: 1.1250 - accuracy: 0.6597 - val_loss: 1.2566 - val_accuracy: 0.6315
# Epoch 44/50
# 781/781 [==============================] - 115s 147ms/step - loss: 1.1211 - accuracy: 0.6607 - val_loss: 1.0709 - val_accuracy: 0.6796
# Epoch 45/50
# 781/781 [==============================] - 122s 156ms/step - loss: 1.1061 - accuracy: 0.6664 - val_loss: 1.0876 - val_accuracy: 0.6780
# Epoch 46/50
# 781/781 [==============================] - 116s 148ms/step - loss: 1.1031 - accuracy: 0.6664 - val_loss: 1.1589 - val_accuracy: 0.6696
# Epoch 47/50
# 781/781 [==============================] - 119s 152ms/step - loss: 1.1029 - accuracy: 0.6666 - val_loss: 1.0759 - val_accuracy: 0.6791
# Epoch 48/50
# 781/781 [==============================] - 124s 158ms/step - loss: 1.0949 - accuracy: 0.6682 - val_loss: 0.9742 - val_accuracy: 0.7076
# Epoch 49/50
# 781/781 [==============================] - 117s 149ms/step - loss: 1.0875 - accuracy: 0.6732 - val_loss: 1.0562 - val_accuracy: 0.6809
# Epoch 50/50
# 781/781 [==============================] - 118s 151ms/step - loss: 1.0840 - accuracy: 0.6727 - val_loss: 0.9604 - val_accuracy: 0.7118
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9604 - accuracy: 0.7118
# Test loss: 0.9604
# Test accuracy: 0.7118
